# %%
import spotipy
import json
import pandas as pd
import unicodedata
from pprint import pprint

# %%
sp = spotipy.Spotify()

# %%
def remove_accents(string):
    return ''.join((c for c in unicodedata.normalize('NFD', string) if unicodedata.category(c) != 'Mn'))

# %%
def search_artist(band_name):
    """
    Calls the Spotify API object and returns only one artist object
    """
    
    try:
        # remove accents and make lowercase
        band_name = remove_accents(band_name).lower()
        
        # call api
        results = sp.search(q=band_name, limit=20, type='artist')
        print("{} => {} artists found".format(band_name, len(results)))
        
        # some manual changes
        if band_name == 'chk chk chk':
            band_name = '!!!'

        # return only one artist
        if results['artists']['total'] > 0:
            return [artist for artist in results['artists']['items'] if remove_accents(artist['name']).lower() == band_name][0]
        else:
            return []

    except:
        print('Error')
        return []

# %%
# Read the festival bands and construct a list of band_names
json_data=open('bands.json').read()
bands = json.loads(json_data)
band_names = [b['name'] for b in bands]

# manually remove some bands
band_names = [b for b in band_names]

# band_names = ['jardin de la croix']
# band_names = band_names[0:10]

# %%
# Get all artists from Spotify API
# all_artists = []
# for band_name in band_names:
#     artist = search_artist(band_name)
#     if len(artist) > 0:
#         all_artists.append(artist)

# persist artists downloaded
with open('spotipy_artists.json', 'w') as fp:
    json.dump(all_artists, fp)
# Out:
# !!! => 1 artists found
# chk chk chk => 1 artists found
# 7 notas 7 colores => 1 artists found
# abdulla rashim => 1 artists found
# about leaving => 1 artists found
# the afghan whigs => 1 artists found
# against me! => 1 artists found
# agorazein => 1 artists found
# aldrin y collins => 1 artists found
# alex cameron => 1 artists found
# alexandra savior => 1 artists found
# alexis taylor => 1 artists found
# alien tango => 1 artists found
# all indians no chief => 1 artists found
# ame live => 1 artists found
# angel olsen => 1 artists found
# angela => 1 artists found
# animic => 1 artists found
# annette peacock => 1 artists found
# aphex twin => 1 artists found
# arcade fire => 1 artists found
# aries => 1 artists found
# aurora halal => 1 artists found
# autarkic live => 1 artists found
# avalon emerson => 1 artists found
# badbadnotgood => 1 artists found
# barbott => 1 artists found
# belako => 1 artists found
# belushi => 1 artists found
# ben ufo => 1 artists found
# berri txarrak => 1 artists found
# bicep => 1 artists found
# the black angels => 1 artists found
# bolga => 1 artists found
# bon iver => 1 artists found
# broken social scene => 1 artists found
# cigarettes after sex => 1 artists found
# clubz => 1 artists found
# cocaine piss => 1 artists found
# dj coco => 1 artists found
# conttra => 1 artists found
# converge => 1 artists found
# the crab apples => 1 artists found
# cymbals eat guitars => 1 artists found
# the damned => 1 artists found
# dave p. => 1 artists found
# Error
# death grips => 1 artists found
# descendents => 1 artists found
# dirty porko & crie930 => 1 artists found
# dirty porko => 1 artists found
# crie930 => 1 artists found
# discos paradiso crew => 1 artists found
# dixon => 1 artists found
# don't dj => 1 artists found
# donallop => 1 artists found
# dj dustin => 1 artists found
# el petit de cal eril => 1 artists found
# elmini => 1 artists found
# elza soares => 1 artists found
# evripidis and his tragedies => 1 artists found
# fairmont live => 1 artists found
# fatima yamaha => 1 artists found
# ferenc => 1 artists found
# flying lotus => 1 artists found
# formation => 1 artists found
# frank ocean => 1 artists found
# front 242 => 1 artists found
# fufanu => 1 artists found
# gas => 1 artists found
# glass animals => 1 artists found
# gojira => 1 artists found
# golden bug => 1 artists found
# gordi => 1 artists found
# grace jones => 1 artists found
# grandaddy => 1 artists found
# the growlers => 1 artists found
# hamilton leithauser => 1 artists found
# the harlock => 1 artists found
# henrik schwarz => 1 artists found
# her little donkey => 1 artists found
# huerco s. => 1 artists found
# hvob => 1 artists found
# ian pooley => 1 artists found
# innercut => 1 artists found
# iosonouncane => 1 artists found
# it's not not => 1 artists found
# jackmaster => 1 artists found
# japandroids => 1 artists found
# jardin de la croix => 1 artists found
# jazz => 1 artists found
# Error
# jeremy jay => 1 artists found
# jmii => 1 artists found
# joey purp => 1 artists found
# john talabot => 1 artists found
# joy orbison => 1 artists found
# julia jacklin => 1 artists found
# julie doiron => 1 artists found
# junun => 1 artists found
# kate tempest => 1 artists found
# keems => 1 artists found
# kelly lee owens => 1 artists found
# kepa junkera & los hermanos cubero => 1 artists found
# kepa junkera => 1 artists found
# los hermanos cubero => 1 artists found
# kevin morby => 1 artists found
# khidja => 1 artists found
# kiasmos => 1 artists found
# king gizzard & the lizard wizard => 1 artists found
# king gizzard => 1 artists found
# Error
# the lizard wizard => 1 artists found
# Error
# king krule => 1 artists found
# kink => 1 artists found
# kokoshca => 1 artists found
# kornel kovacs => 1 artists found
# lady wray => 1 artists found
# lauer => 1 artists found
# les cruet => 1 artists found
# les sueques => 1 artists found
# let's eat grandma => 1 artists found
# local natives => 1 artists found
# lord of the isles => 1 artists found
# lvl up => 1 artists found
# mac demarco => 1 artists found
# the magnetic fields => 1 artists found
# the make-up => 1 artists found
# mannequin pussy => 1 artists found
# maquina total => 1 artists found
# marc pinol => 1 artists found
# maresme => 1 artists found
# marie davidson => 1 artists found
# marta delmont => 1 artists found
# marvin & guy => 1 artists found
# matrixxman => 1 artists found
# medalla => 1 artists found
# Error
# melange => 1 artists found
# metronomy => 1 artists found
# michael mayer => 1 artists found
# miguel => 1 artists found
# mishima => 1 artists found
# mitski => 1 artists found
# the molochs => 1 artists found
# moscoman => 1 artists found
# muneco => 1 artists found
# murdoc => 1 artists found
# museless => 1 artists found
# the mystery lights => 1 artists found
# neleonard => 1 artists found
# nikki lane => 1 artists found
# no crafts => 1 artists found
# no zu => 1 artists found
# noga erez => 1 artists found
# nots => 1 artists found
# ocellot => 1 artists found
# odina => 1 artists found
# operators => 1 artists found
# papa topo => 1 artists found
# patrick codenys (front 242) => 1 artists found
# Error
# pavvla => 1 artists found
# pearson sound => 1 artists found
# pedro vian => 1 artists found
# pender street steppers => 1 artists found
# phurpa => 1 artists found
# pinegrove => 1 artists found
# playback maracas => 1 artists found
# polar inertia => 1 artists found
# polseguera => 1 artists found
# pond => 1 artists found
# preoccupations => 1 artists found
# priests => 1 artists found
# rebuig => 1 artists found
# recondite => 1 artists found
# regalim => 1 artists found
# retirada! => 1 artists found
# romare => 1 artists found
# rosalia & raul refree => 1 artists found
# rosalia => 1 artists found
# raul refree => 1 artists found
# Error
# royal trux => 1 artists found
# run the jewels => 1 artists found
# ryder the eagle => 1 artists found
# s u r v i v e => 1 artists found
# saint etienne => 1 artists found
# salfvman => 1 artists found
# sampha => 1 artists found
# sau poler => 1 artists found
# seu jorge => 1 artists found
# shelby grey => 1 artists found
# shellac => 1 artists found
# silent james => 1 artists found
# sinkane => 1 artists found
# skepta => 1 artists found
# skinny puppy => 1 artists found
# slayer => 1 artists found
# sleaford mods => 1 artists found
# sleep => 1 artists found
# slim cessna's auto club => 1 artists found
# solange => 1 artists found
# soledad velez => 1 artists found
# sorry kate => 1 artists found
# swans => 1 artists found
# swet shop boys => 1 artists found
# talaboman => 1 artists found
# teenage fanclub => 1 artists found
# dj tennis => 1 artists found
# this is not this heat => 1 artists found
# triangulo de amor bizarro => 1 artists found
# tuff city kids => 1 artists found
# tycho => 1 artists found
# vaadat charigim => 1 artists found
# valius + carlora serrahima => 1 artists found
# valius => 1 artists found
# carlota serrahima => 1 artists found
# van morrison => 1 artists found
# vladimir ivkovic => 1 artists found
# vox low => 1 artists found
# wand => 1 artists found
# the waterparties => 1 artists found
# the wave pictures => 1 artists found
# the wedding present => 1 artists found
# weval => 1 artists found
# weyes blood => 1 artists found
# the wheels => 1 artists found
# whitney => 1 artists found
# wild beasts => 1 artists found
# william tyler => 1 artists found
# the xx => 1 artists found
# youandewan => 1 artists found
# young marco => 1 artists found
# the zombies => 1 artists found
# adelaida => 1 artists found
# aeromocas e tenistas russas => 1 artists found
# astronaut project => 1 artists found
# bike => 1 artists found
# billy carter => 1 artists found
# de monaco => 1 artists found
# diealright => 1 artists found
# Error
# entropia => 1 artists found
# escorpio => 1 artists found
# fingerfingerrr => 1 artists found
# g-c => 1 artists found
# Error
# gold class => 1 artists found
# hanba! => 1 artists found
# Error
# inzul => 1 artists found
# jaaa! => 1 artists found
# joel sarakula => 1 artists found
# leyya => 1 artists found
# ligula => 1 artists found
# liniker e os caramelows => 1 artists found
# marley bloo => 1 artists found
# marrakesh => 1 artists found
# me & the plant => 1 artists found
# Error
# meridian response => 1 artists found
# miss garrison => 1 artists found
# no metal in this battle => 1 artists found
# patients => 1 artists found
# persian pelican => 1 artists found
# prairie wwww => 1 artists found
# radio 123 => 1 artists found
# rbp => 1 artists found
# Error
# riviere => 1 artists found
# shao => 1 artists found
# sharman den => 1 artists found
# shijo x => 1 artists found
# skegss => 1 artists found
# tie => 1 artists found
# tired lion => 1 artists found
# tourista => 1 artists found
# wrongonyou => 1 artists found

# %%
# Extract all genres
all_genres = []
for a in all_artists:
    all_genres.extend(a['genres'])

# %%
# plot a histogram with all genres
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

genres = pd.DataFrame(all_genres, columns=['genre'])
genres.apply(pd.value_counts).plot(kind='bar')

# %%
# explore the most common words used in the genres
all_genres_string = ' '.join(all_genres)

from collections import Counter
words = all_genres_string.split()
wordCount = Counter(words)
wordCount.most_common
# Out:
# <bound method Counter.most_common of Counter({'rock': 147, 'pop': 143, 'indie': 141, 'house': 71, 'chamber': 47, 'psych': 45, 'noise': 44, 'alternative': 42, 'garage': 38, 'folk': 38, 'new': 30, 'spanish': 29, 'deep': 28, 'r&b': 28, 'indietronica': 27, 'punk': 24, 'neo-psychedelic': 24, 'float': 23, 'metal': 23, 'minimal': 22, 'dance': 19, 'wave': 19, 'hop': 18, 'lo-fi': 18, 'hip': 17, 'microhouse': 17, 'techno': 17, 'freak': 16, 'slow': 16, 'core': 16, 'electronic': 15, 'dream': 15, 'nu': 14, 'folk-pop': 14, 'preverb': 14, 'room': 13, 'escape': 13, 'outsider': 13, 'tech': 13, 'and': 12, 'experimental': 12, 'dance-punk': 11, 'holler': 